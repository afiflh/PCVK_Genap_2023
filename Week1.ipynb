# %% [markdown]
# <a href="https://colab.research.google.com/github/afiflh/PCVK_Genap_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
#list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/777"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image menjadi ukuran separuh
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # convert warna menjadi RGB
  final_frame = cv.hconcat((image, image_2))      # menyatukan gambar
  cv2_imshow(final_frame)                         # menampilkan gambar
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x388>

# %%
# Melihat ukuran file image
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  388  x  400
# <PIL.Image.Image image mode=RGB size=400x388>

# %%
# mengakses pixel dengan memberi garis diagonal menyilang = Accessing pixel by creating lines in image

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for y in  range (lebar):
  image_3[int((tinggi)/2),y] = [0,0,0]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x388>

# %%
#PERTANYAAN
1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
menggunakan Google Colab?
2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
4. Perhatikan potongan kode progam berikut :
#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]
Apakah kegunaan kode [255,255,255] ? Jelaskan!
5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
rendah!

JAWAB
1. Google Colab dapat disimpan pada repository suatu akun di Github jadi mungkin
dapat mempermudah menyimpan progres kerja kita di dalam akun Github kita secara
langsung

2. Library: - NumPy adalah perpustakaan fundamental untuk komputasi ilmiah dalam
              Python. Ini menyediakan objek array multidimensi yang cepat dan
              efisien, bersama dengan berbagai fungsi matematika untuk memanipulasi
              array.
            - Pandas adalah perpustakaan yang digunakan untuk analisis data dan
              manipulasi data berstruktur.
            - cv2 dalah perpustakaan sumber terbuka yang digunakan untuk pengolahan
              citra dan komputer visi. Ini memiliki berbagai fungsi untuk membaca,
              mengubah, memanipulasi, dan menganalisis gambar.
            - google.colab.patches.cv2_imshow: Ini adalah bagian dari Google Colab
              dan digunakan untuk menampilkan gambar dengan menggunakan perpustakaan
              OpenCV (cv2). Ini digunakan khusus untuk lingkungan Colab.
            - skimage.io (io): Modul io dari scikit-image (skimage) digunakan
              untuk membaca dan menulis gambar dalam berbagai format.
            - skimage.transform (transform): Modul transform dalam scikit-image
              (skimage) menyediakan berbagai fungsi untuk transformasi geometris
              pada gambar, seperti pergeseran, rotasi, penskalaan, dll.
            - PIL adalah perpustakaan yang digunakan untuk bekerja dengan gambar
              dalam Python. Ini menyediakan berbagai fungsi untuk membuka,
              menyimpan, dan memanipulasi gambar.
            - Matplotlib adalah perpustakaan untuk membuat visualisasi dalam bahasa
              pemrograman Python. Modul pylab dari Matplotlib umumnya digunakan
              untuk membuat plot grafik dan juga dapat digunakan untuk menampilkan
              gambar.
  Semuanya digunakan tergantung dengan fungsi masing-masing library, jadi tidak
  semua diimport dalam sebuah project pengolahan citra hanya digunakan sesuai kebutuhan.

3. Kegunaan dari potongan kode tersebut digunakan untuk mengubah ukuran gambar
dengan faktor penskalaan horizontal (fx) dan vertikal (fy) sebesar 0,5. Dalam hal
ini, gambar akan diperkecil menjadi setengah ukuran aslinya baik secara horizontal
maupun vertikal. Dan jika tidak dilakukan terdapat pengaruh yaitu gambar akan tetap
berukuran sama seperti aslinya. Ini mungkin menjadi masalah jika Anda perlu mengurangi
konsumsi sumber daya atau menyesuaikan tampilan gambar. Juga, gambar yang besar dapat
memperlambat proses pengolahan atau memakan lebih banyak ruang penyimpanan.

4. Kode [255, 255, 255] dalam potongan program tersebut mewakili nilai warna putih
dalam format citra berwarna yang menggunakan skema warna RGB (Red, Green, Blue).
Dalam skema warna ini, setiap nilai warna (merah, hijau, dan biru) direpresentasikan
dalam rentang 0 hingga 255, di mana 0 mengindikasikan ketiadaan warna dan 255
mengindikasikan intensitas maksimal warna.

5. Berikut keterkaitan antara pixel dan resolusi gambar:
   1. Jika resolusi tinggi dan banyak pixel, maka gambar dengan resolusi tinggi
   memiliki lebih banyak piksel, yang memungkinkannya menangkap detail yang lebih halus.
   2. Jika resolusi rendah dan sedikit pixel, maka gambar dengan resolusi rendah
